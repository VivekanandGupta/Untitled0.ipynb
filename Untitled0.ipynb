# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekanandGupta/Untitled0.ipynb/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv("/content/GOOG.csv")

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
# <ipython-input-4-3d1443e590ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 8s 92ms/step - loss: 0.0045 - mean_absolute_error: 0.0485 - val_loss: 0.0253 - val_mean_absolute_error: 0.1395
# Epoch 2/80
# 30/30 [==============================] - 1s 49ms/step - loss: 7.2708e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0056 - val_mean_absolute_error: 0.0589
# Epoch 3/80
# 30/30 [==============================] - 1s 49ms/step - loss: 5.7542e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0080 - val_mean_absolute_error: 0.0741
# Epoch 4/80
# 30/30 [==============================] - 1s 49ms/step - loss: 5.1366e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0074 - val_mean_absolute_error: 0.0713
# Epoch 5/80
# 30/30 [==============================] - 2s 51ms/step - loss: 5.0584e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0060 - val_mean_absolute_error: 0.0634
# Epoch 6/80
# 30/30 [==============================] - 1s 49ms/step - loss: 5.2700e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0051 - val_mean_absolute_error: 0.0578
# Epoch 7/80
# 30/30 [==============================] - 2s 83ms/step - loss: 4.8243e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0053 - val_mean_absolute_error: 0.0604
# Epoch 8/80
# 30/30 [==============================] - 2s 56ms/step - loss: 5.2627e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0068 - val_mean_absolute_error: 0.0699
# Epoch 9/80
# 30/30 [==============================] - 1s 50ms/step - loss: 4.5540e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0040 - val_mean_absolute_error: 0.0510
# Epoch 10/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.8299e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0061 - val_mean_absolute_error: 0.0667
# Epoch 11/80
# 30/30 [==============================] - 2s 51ms/step - loss: 3.7853e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0057 - val_mean_absolute_error: 0.0634
# Epoch 12/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.7842e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0051 - val_mean_absolute_error: 0.0598
# Epoch 13/80
# 30/30 [==============================] - 2s 55ms/step - loss: 4.0147e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0055 - val_mean_absolute_error: 0.0622
# Epoch 14/80
# 30/30 [==============================] - 2s 55ms/step - loss: 3.3511e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0048 - val_mean_absolute_error: 0.0566
# Epoch 15/80
# 30/30 [==============================] - 2s 83ms/step - loss: 3.0831e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0044 - val_mean_absolute_error: 0.0540
# Epoch 16/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.8095e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0065 - val_mean_absolute_error: 0.0677
# Epoch 17/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.0603e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0062 - val_mean_absolute_error: 0.0659
# Epoch 18/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.9396e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0029 - val_mean_absolute_error: 0.0420
# Epoch 19/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.0085e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0053 - val_mean_absolute_error: 0.0597
# Epoch 20/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.8940e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0042 - val_mean_absolute_error: 0.0520
# Epoch 21/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.7939e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0042 - val_mean_absolute_error: 0.0511
# Epoch 22/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.9483e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0035 - val_mean_absolute_error: 0.0464
# Epoch 23/80
# 30/30 [==============================] - 2s 75ms/step - loss: 2.8143e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0029 - val_mean_absolute_error: 0.0418
# Epoch 24/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.6784e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0045 - val_mean_absolute_error: 0.0543
# Epoch 25/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.9876e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0085 - val_mean_absolute_error: 0.0801
# Epoch 26/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.7478e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0035 - val_mean_absolute_error: 0.0476
# Epoch 27/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.7038e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0056 - val_mean_absolute_error: 0.0630
# Epoch 28/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.6629e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0046 - val_mean_absolute_error: 0.0552
# Epoch 29/80
# 30/30 [==============================] - 3s 96ms/step - loss: 2.6081e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0023 - val_mean_absolute_error: 0.0362
# Epoch 30/80
# 30/30 [==============================] - 2s 77ms/step - loss: 2.6242e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0029 - val_mean_absolute_error: 0.0424
# Epoch 31/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.3559e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0042 - val_mean_absolute_error: 0.0536
# Epoch 32/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.3934e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0035 - val_mean_absolute_error: 0.0475
# Epoch 33/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.6681e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0041 - val_mean_absolute_error: 0.0526
# Epoch 34/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.5438e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0037 - val_mean_absolute_error: 0.0505
# Epoch 35/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.5654e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0040 - val_mean_absolute_error: 0.0518
# Epoch 36/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.4161e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0029 - val_mean_absolute_error: 0.0423
# Epoch 37/80
# 30/30 [==============================] - 3s 86ms/step - loss: 2.1711e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0039 - val_mean_absolute_error: 0.0511
# Epoch 38/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.0946e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0019 - val_mean_absolute_error: 0.0328
# Epoch 39/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.1825e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0036 - val_mean_absolute_error: 0.0498
# Epoch 40/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.3714e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0046 - val_mean_absolute_error: 0.0577
# Epoch 41/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.1825e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0028 - val_mean_absolute_error: 0.0432
# Epoch 42/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.0842e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0024 - val_mean_absolute_error: 0.0395
# Epoch 43/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9736e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 44/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.9086e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0041 - val_mean_absolute_error: 0.0533
# Epoch 45/80
# 30/30 [==============================] - 2s 78ms/step - loss: 1.8826e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0042 - val_mean_absolute_error: 0.0541
# Epoch 46/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.9801e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 47/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.0145e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0016 - val_mean_absolute_error: 0.0320
# Epoch 48/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.8799e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0026 - val_mean_absolute_error: 0.0426
# Epoch 49/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.8207e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374
# Epoch 50/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.7532e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 51/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.7842e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 52/80
# 30/30 [==============================] - 2s 75ms/step - loss: 1.7806e-04 - mean_absolute_error: 0.0098 - val_loss: 9.8690e-04 - val_mean_absolute_error: 0.0239
# Epoch 53/80
# 30/30 [==============================] - 2s 69ms/step - loss: 1.9203e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0036 - val_mean_absolute_error: 0.0510
# Epoch 54/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.8390e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 55/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.7815e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 56/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.8546e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0043 - val_mean_absolute_error: 0.0566
# Epoch 57/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.8654e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 58/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.5876e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 59/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.6491e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 60/80
# 30/30 [==============================] - 3s 88ms/step - loss: 1.6276e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 61/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.4440e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0023 - val_mean_absolute_error: 0.0406
# Epoch 62/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.6051e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 63/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.6441e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 64/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.6734e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0030 - val_mean_absolute_error: 0.0459
# Epoch 65/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.7023e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 66/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.5310e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0020 - val_mean_absolute_error: 0.0366
# Epoch 67/80
# 30/30 [==============================] - 2s 69ms/step - loss: 1.4911e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0023 - val_mean_absolute_error: 0.0403
# Epoch 68/80
# 30/30 [==============================] - 2s 74ms/step - loss: 1.4756e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0026 - val_mean_absolute_error: 0.0436
# Epoch 69/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.5460e-04 - mean_absolute_error: 0.0088 - val_loss: 7.8545e-04 - val_mean_absolute_error: 0.0205
# Epoch 70/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.4093e-04 - mean_absolute_error: 0.0085 - val_loss: 9.6050e-04 - val_mean_absolute_error: 0.0237
# Epoch 71/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.3932e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 72/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.3330e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0016 - val_mean_absolute_error: 0.0324
# Epoch 73/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.4277e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 74/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.3715e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 75/80
# 30/30 [==============================] - 2s 81ms/step - loss: 1.3542e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0024 - val_mean_absolute_error: 0.0403
# Epoch 76/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.3392e-04 - mean_absolute_error: 0.0084 - val_loss: 5.9023e-04 - val_mean_absolute_error: 0.0187
# Epoch 77/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.3941e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0023 - val_mean_absolute_error: 0.0409
# Epoch 78/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.2823e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 79/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.2608e-04 - mean_absolute_error: 0.0080 - val_loss: 9.6720e-04 - val_mean_absolute_error: 0.0249
# Epoch 80/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.2068e-04 - mean_absolute_error: 0.0078 - val_loss: 9.8361e-04 - val_mean_absolute_error: 0.0242

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 22ms/step
# array([[0.4866767 , 0.48398995],
#        [0.4929721 , 0.489924  ],
#        [0.49814385, 0.49491447],
#        [0.5145926 , 0.51167816],
#        [0.523997  , 0.5206904 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[0.4866767 , 0.48398995],
#        [0.4929721 , 0.489924  ],
#        [0.49814385, 0.49491447],
#        [0.5145926 , 0.51167816],
#        [0.523997  , 0.5206904 ]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                 open     close  open_predicted  close_predicted
# date
# 2020-08-24  0.497853  0.496369        0.486677         0.483990
# 2020-08-25  0.491429  0.507171        0.492972         0.489924
# 2020-08-26  0.505416  0.530998        0.498144         0.494914
# 2020-08-27  0.530055  0.521259        0.514593         0.511678
# 2020-08-28  0.519165  0.526698        0.523997         0.520690

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# Out:
# <ipython-input-25-3796df6ba6f4>:3: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# <ipython-input-25-3796df6ba6f4>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                 open     close  open_predicted  close_predicted
# 2021-06-09  0.986289  0.983705        0.949513         0.922869
# 2021-06-10  0.983327  1.000000        0.955234         0.927734
# 2021-06-11  1.000000  0.995862        0.961919         0.933794
# 2021-06-12       NaN       NaN             NaN              NaN
# 2021-06-13       NaN       NaN             NaN              NaN
# 2021-06-14       NaN       NaN             NaN              NaN
# 2021-06-15       NaN       NaN             NaN              NaN
# 2021-06-16       NaN       NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
